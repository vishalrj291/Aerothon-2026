# %%
import pandas as pd

df = pd.read_csv("../dataset 2/turbojet_complete_dataset.csv")

df.head()
# Out:
#    EngineID  Cycle    Altitude_m      Mach      Tamb_K       Pamb_Pa  \
# 0         1      1   7193.924837  0.141126  240.052081  39779.103968
# 1         1      2   4452.604045  0.411272  259.891025  58203.855705
# 2         1      3  11063.427429  0.234292  217.697941  23132.702172
# 3         1      4   9654.382398  0.067393  227.596058  28176.090834
# 4         1      5   7687.908866  0.801668  241.985939  37542.909693
#
#     RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K          P3_Pa  \
# 0  37691.735948       0.301736   76228.313402  302.370205   74966.683275
# 1  69050.933769       0.564713  373737.913690  462.439391  350404.191201
# 2  62807.616035       0.749030  118005.706065  363.102490  109746.611623
# 3  79262.159619       1.580127  188014.330164  420.759865  181026.314204
# 4  54514.702852       0.411448  212538.513945  411.864614  199843.620053
#
#           T3_K          P4_Pa         T4_K  CompressorHealth  CombustorHealth  \
# ...

# %%
df.shape
# Out:
# (300, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EngineID          300 non-null    int64
#  1   Cycle             300 non-null    int64
#  2   Altitude_m        300 non-null    float64
#  3   Mach              300 non-null    float64
#  4   Tamb_K            300 non-null    float64
#  5   Pamb_Pa           300 non-null    float64
#  6   RPM_rev_min       300 non-null    float64
#  7   FuelFlow_kg_s     300 non-null    float64
#  8   P2_Pa             300 non-null    float64
#  9   T2_K              300 non-null    float64
#  10  P3_Pa             300 non-null    float64
#  11  T3_K              300 non-null    float64
#  12  P4_Pa             300 non-null    float64
#  13  T4_K              300 non-null    float64
#  14  CompressorHealth  300 non-null    float64
#  15  CombustorHealth   300 non-null    float64
# ...

# %%
df.describe()
# Out:
#         EngineID       Cycle    Altitude_m        Mach      Tamb_K  \
# count  300.00000  300.000000    300.000000  300.000000  300.000000
# mean     5.50000   15.500000   5830.980490    0.447013  250.260899
# std      2.87708    8.669903   3353.584110    0.257749   21.976754
# min      1.00000    1.000000     17.793517    0.002933  208.171037
# 25%      3.00000    8.000000   2968.436813    0.232121  233.740481
# 50%      5.50000   15.500000   6001.265584    0.446696  248.771944
# 75%      8.00000   23.000000   8472.684935    0.665959  269.197223
# max     10.00000   30.000000  12053.311094    0.902138  294.517485
#
#              Pamb_Pa   RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K  \
# count     300.000000    300.000000     300.000000     300.000000  300.000000
# mean    52449.900082  54854.217350       1.066888  227512.356003  398.904877
# std     23229.245316  14762.492706       0.541926  160059.164077   79.383330
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df.isnull().sum()
# Out:
# EngineID            0
# Cycle               0
# Altitude_m          0
# Mach                0
# Tamb_K              0
# Pamb_Pa             0
# RPM_rev_min         0
# FuelFlow_kg_s       0
# P2_Pa               0
# T2_K                0
# P3_Pa               0
# T3_K                0
# P4_Pa               0
# T4_K                0
# CompressorHealth    0
# CombustorHealth     0
# TurbineHealth       0
# OverallHealth       0
# Thrust_N            0
# TSFC_g_N_s          0
# dtype: int64

# %%
df["EngineID"].nunique()
# Out:
# 10

# %%
df["EngineID"].value_counts().sort_index()
# Out:
# EngineID
# 1     30
# 2     30
# 3     30
# 4     30
# 5     30
# 6     30
# 7     30
# 8     30
# 9     30
# 10    30
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Unique Engines:", df["EngineID"].nunique())
# Out:
# Unique Engines: 10

# %%
df["EngineID"].value_counts().sort_index()
# Out:
# EngineID
# 1     30
# 2     30
# 3     30
# 4     30
# 5     30
# 6     30
# 7     30
# 8     30
# 9     30
# 10    30
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,6)
sns.set_style("whitegrid")

# %%
plt.hist(df["RPM_rev_min"], bins=20)

plt.title("Distribution of RPM")

plt.xlabel("RPM")

plt.ylabel("Frequency")

plt.show()

# %%
plt.hist(df["FuelFlow_kg_s"], bins=20)

plt.title("Fuel Flow Distribution")

plt.xlabel("Fuel Flow (kg/s)")

plt.ylabel("Frequency")

plt.show()

# %%
plt.hist(df["Thrust_N"], bins=20)

plt.title("Thrust Distribution")

plt.xlabel("Thrust (N)")

plt.ylabel("Frequency")

plt.show()

# %%
plt.hist(df["OverallHealth"], bins=20)

plt.title("Overall Health Distribution")

plt.xlabel("Health")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(16,12))

corr = df.corr(numeric_only=True)

sns.heatmap(corr,
            cmap="coolwarm",
            annot=True,
            fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["RPM_rev_min"],
            df["Thrust_N"])

plt.xlabel("RPM")

plt.ylabel("Thrust")

plt.title("RPM vs Thrust")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["FuelFlow_kg_s"],
            df["Thrust_N"])

plt.xlabel("Fuel Flow")

plt.ylabel("Thrust")

plt.title("Fuel Flow vs Thrust")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["Cycle"],
            df["OverallHealth"])

plt.xlabel("Cycle")

plt.ylabel("Overall Health")

plt.title("Health vs Cycle")

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(df["Cycle"], df["CompressorHealth"], 'r.', label="Compressor")

plt.plot(df["Cycle"], df["CombustorHealth"], 'g.', label="Combustor")

plt.plot(df["Cycle"], df["TurbineHealth"], 'b.', label="Turbine")

plt.xlabel("Cycle")
plt.ylabel("Health")

plt.title("Subsystem Health vs Cycle")

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["P2_Pa"], df["CompressorHealth"])

plt.xlabel("P2 Pressure")

plt.ylabel("Compressor Health")

plt.title("Compressor Health vs P2")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["T3_K"], df["CombustorHealth"])

plt.xlabel("T3")

plt.ylabel("Combustor Health")

plt.title("Combustor Health vs T3")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["T4_K"], df["TurbineHealth"])

plt.xlabel("T4")

plt.ylabel("Turbine Health")

plt.title("Turbine Health vs T4")

plt.show()

# %% [markdown]
# # =====================================
# # Feature Engineering
# # ========================================

# %%
df["CompressorPressureRatio"] = df["P2_Pa"] / df["Pamb_Pa"]

# %%
df[["P2_Pa","Pamb_Pa","CompressorPressureRatio"]].head()
# Out:
#            P2_Pa       Pamb_Pa  CompressorPressureRatio
# 0   76228.313402  39779.103968                 1.916290
# 1  373737.913690  58203.855705                 6.421188
# 2  118005.706065  23132.702172                 5.101250
# 3  188014.330164  28176.090834                 6.672832
# 4  212538.513945  37542.909693                 5.661216

# %%
# Compressor Pressure Ratio vs Compressor Health

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["CompressorPressureRatio"],
            df["CompressorHealth"])

plt.xlabel("Compressor Pressure Ratio")

plt.ylabel("Compressor Health")

plt.title("Compressor Pressure Ratio vs Compressor Health")

plt.grid(True)

plt.show()

# %%
# Compressor Temperature Rise

# %%
df["CompressorTempRise"] = df["T2_K"] - df["Tamb_K"]

# %%
df[["Tamb_K","T2_K","CompressorTempRise"]].head()
# Out:
#        Tamb_K        T2_K  CompressorTempRise
# 0  240.052081  302.370205           62.318124
# 1  259.891025  462.439391          202.548366
# 2  217.697941  363.102490          145.404548
# 3  227.596058  420.759865          193.163807
# 4  241.985939  411.864614          169.878675

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["CompressorTempRise"],
    df["CompressorHealth"]
)

plt.xlabel("Compressor Temperature Rise")

plt.ylabel("Compressor Health")

plt.title("Compressor Temperature Rise vs Compressor Health")

plt.grid(True)

plt.show()

# %%
df[["CompressorTempRise", "CompressorHealth"]].corr()
# Out:
#                     CompressorTempRise  CompressorHealth
# CompressorTempRise            1.000000         -0.005299
# CompressorHealth             -0.005299          1.000000

# %%
# Combustor Pressure Loss

# %%
df["CombustorPressureLoss"] = (df["P2_Pa"] - df["P3_Pa"]) / df["P2_Pa"]

# %%
df[["P2_Pa", "P3_Pa", "CombustorPressureLoss"]].head()
# Out:
#            P2_Pa          P3_Pa  CombustorPressureLoss
# 0   76228.313402   74966.683275               0.016551
# 1  373737.913690  350404.191201               0.062433
# 2  118005.706065  109746.611623               0.069989
# 3  188014.330164  181026.314204               0.037167
# 4  212538.513945  199843.620053               0.059730

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["CombustorPressureLoss"],
    df["CombustorHealth"]
)

plt.xlabel("Combustor Pressure Loss")
plt.ylabel("Combustor Health")
plt.title("Combustor Pressure Loss vs Combustor Health")

plt.grid(True)
plt.show()

# %% [markdown]
# # Phase 5 — Feature Validation
# # 1. CompressorPressureRatio
# # 2. CompressorTempRise
# # 3. CombustorPressureLoss

# %%
new_features = [
    "CompressorPressureRatio",
    "CompressorTempRise",
    "CombustorPressureLoss",
    "CompressorHealth",
    "CombustorHealth"
]

df[new_features].corr()
# Out:
#                          CompressorPressureRatio  CompressorTempRise  \
# CompressorPressureRatio                 1.000000            0.933768
# CompressorTempRise                      0.933768            1.000000
# CombustorPressureLoss                   0.005619           -0.049835
# CompressorHealth                        0.154139           -0.005299
# CombustorHealth                         0.106212           -0.044233
#
#                          CombustorPressureLoss  CompressorHealth  \
# CompressorPressureRatio               0.005619          0.154139
# CompressorTempRise                   -0.049835         -0.005299
# CombustorPressureLoss                 1.000000          0.015763
# CompressorHealth                      0.015763          1.000000
# CombustorHealth                      -0.017699          0.878883
#
#                          CombustorHealth
# CompressorPressureRatio         0.106212
# CompressorTempRise             -0.044233
# ...

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df[new_features].corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Physics-Based Feature Correlation")

plt.show()

# %%
target_cols = [
    "CompressorHealth",
    "CombustorHealth",
    "TurbineHealth",
    "OverallHealth",
    "Thrust_N",
    "TSFC_g_N_s"
]

sensor_cols = [
    "Altitude_m",
    "Mach",
    "Tamb_K",
    "Pamb_Pa",
    "RPM_rev_min",
    "FuelFlow_kg_s",
    "P2_Pa",
    "T2_K",
    "P3_Pa",
    "T3_K",
    "P4_Pa",
    "T4_K"
]

corr = df[sensor_cols + target_cols].corr()

plt.figure(figsize=(14,10))

sns.heatmap(
    corr.loc[sensor_cols, target_cols],
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Sensor vs Target Correlation")

plt.show()

# %%
df = pd.read_csv("../dataset 2/turbojet_complete_dataset.csv")

print(df.columns)

print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../dataset 2/turbojet_complete_dataset.csv")
#       3 print(df.columns)
#       5 print(df.shape)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

df = pd.read_csv("../dataset 2/turbojet_complete_dataset.csv")

df.head()
# Out:
#    EngineID  Cycle   Altitude_m      Mach      Tamb_K       Pamb_Pa  \
# 0         1      1  6391.400326  0.013071  247.961342  44663.019142
# 1         1      2  8094.115831  0.426328  232.971803  34847.690668
# 2         1      3  5108.850362  0.419662  248.569962  53743.389845
# 3         1      4  5510.229911  0.794202  251.641260  50370.981567
# 4         1      5  3882.477319  0.287350  264.123292  63178.800267
#
#     RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K          P3_Pa  \
# 0  76976.862216       1.841626  295023.850905  444.508752  277243.515880
# 1  70827.994213       0.722787  234572.704922  432.688724  218684.205137
# 2  48709.106809       1.031809  194470.405083  384.372748  186718.401292
# 3  60164.742571       1.287115  360607.880595  469.425633  345146.378231
# 4  44293.257790       1.953395  185257.095576  374.423311  170262.946815
#
#           T3_K          P4_Pa         T4_K  CompressorHealth  CombustorHealth  \
# ...

# %%
df.shape
# Out:
# (30000, 20)

# %%
import pandas as pd

df = pd.read_csv("../dataset 2/turbojet_complete_dataset.csv" \
"")
print(df.columns.tolist())
# Out:
# ['EngineID', 'Cycle', 'Altitude_m', 'Mach', 'Tamb_K', 'Pamb_Pa', 'RPM_rev_min', 'FuelFlow_kg_s', 'P2_Pa', 'T2_K', 'P3_Pa', 'T3_K', 'P4_Pa', 'T4_K', 'CompressorHealth', 'CombustorHealth', 'TurbineHealth', 'OverallHealth', 'Thrust_N', 'TSFC_g_N_s']
